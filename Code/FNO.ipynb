# %%
from FNOhelper.fnoHelper import *
# Define configs to test
configs = [
    {'save_path': 'datasetsFNO/32_32', 'n_modes': (16, 16), 'hidden_channels': 64, 'in_channels': 3, 'out_channels': 6, 'n_layers': 4},
    {'save_path': 'modelsFNO/1000_32_32', 'n_modes': (16, 16), 'hidden_channels': 64, 'in_channels': 3, 'out_channels': 2, 'n_layers': 4},
]

train_config(**configs[1])
# # Train models with different hyperparameters
# for config in configs[:1]:
#     train_config(**config)
# Out:
# using standard method to load data to device.
# using standard method to compute loss.
# self.override_load_to_device=False
# self.overrides_loss=False
# Epoch 0: Train Error: 31.04644943237305
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       2 # Define configs to test
#       3 configs = [
#       4     {'save_path': 'datasetsFNO/32_32', 'n_modes': (16, 16), 'hidden_channels': 64, 'in_channels': 3, 'out_channels': 6, 'n_layers': 4},
#       5     {'save_path': 'modelsFNO/1000_32_32', 'n_modes': (16, 16), 'hidden_channels': 64, 'in_channels': 3, 'out_channels': 2, 'n_layers': 4},
#       6 ]
# ----> 8 train_config(**configs[1])
#       9 # # Train models with different hyperparameters
#      10 # for config in configs[:1]:
#      11 #     train_config(**config)
#
# File c:\Users\Radu Vasilache\Documents\StudiumTUM\Bachelorarbeit\Code\FNOhelper\fnoHelper.py:64, in train_config(save_path, n_modes, hidden_channels, in_channels, out_channels, n_layers)
#      62 try:
#      63     start_time = default_timer()
# ---> 64     trainer.train(
#      65         train_loader=train_loader,
#      66         test_loaders=test_loaders,
#      67         optimizer=optimizer,
#      68         scheduler=scheduler,
#      69         regularizer=None,
#      70         training_loss=train_loss,
#      71         eval_losses=eval_losses
#      72     )
#      74 except Exception as e:
#      75     print(f"Exception: {e}")
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\neuralop\training\trainer.py:192, in Trainer.train(self, train_loader, test_loaders, optimizer, scheduler, regularizer, training_loss, eval_losses)
#     189 loss.backward()
#     190 del out
# --> 192 optimizer.step()
#     193 train_err += loss.item()
#     195 with torch.no_grad():
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\lr_scheduler.py:130, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     128 opt = opt_ref()
#     129 opt._opt_called = True  # type: ignore[union-attr]
# --> 130 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\adam.py:226, in Adam.step(self, closure)
#     214     beta1, beta2 = group["betas"]
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     223         state_steps,
#     224     )
# --> 226     adam(
#     227         params_with_grad,
#     228         grads,
#     229         exp_avgs,
#     230         exp_avg_sqs,
#     231         max_exp_avg_sqs,
#     232         state_steps,
#     233         amsgrad=group["amsgrad"],
#     234         has_complex=has_complex,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\adam.py:766, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     763 else:
#     764     func = _single_tensor_adam
# --> 766 func(
#     767     params,
#     768     grads,
#     769     exp_avgs,
#     770     exp_avg_sqs,
#     771     max_exp_avg_sqs,
#     772     state_steps,
#     773     amsgrad=amsgrad,
#     774     has_complex=has_complex,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785 )
#
# File c:\ProgramData\anaconda3\envs\i2dl\Lib\site-packages\torch\optim\adam.py:534, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     529         device_grads = torch._foreach_add(  # type: ignore[assignment]
#     530             device_grads, device_params, alpha=weight_decay
#     531         )
#     533 # Decay the first and second moment running average coefficient
# --> 534 torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
#     536 torch._foreach_mul_(device_exp_avg_sqs, beta2)
#     537 torch._foreach_addcmul_(
#     538     device_exp_avg_sqs, device_grads, device_grads, 1 - beta2
#     539 )
#
# KeyboardInterrupt:

# %%
import numpy as np
def inquire(save_path):
    input_data = np.load(f'{save_path}/input_data.npy')
    output_data = np.load(f'{save_path}/output_data.npy')

    assert not np.isnan(input_data).any(), "NaNs found in inputs"
    assert not np.isnan(output_data).any(), "NaNs found in outputs" # They are found here
    assert not np.isinf(input_data).any(), "Infinities found in inputs"
    assert not np.isinf(output_data).any(), "Infinities found in outputs" # They are found here
    print(input_data.shape)
    print(output_data.shape)

inquire('modelsFNO/500_32_32_3')
# Out:
# (500, 32, 32, 3)
# (500, 32, 32, 2)
